# %% [markdown]
# # Visualize Term Frequency Distributions
#
# This notebook demonstrates how to visualize term frequency distributions using Rosette API via the `/morphology/lemmas` endpoint.  You can check out the code on [GitHub](https://github.com/zyocum/compare-vocabulary/blob/master/README.md).
#
# ## Setup
#
# The first section imports the [Rosette API Python binding module](https://github.com/rosette-api/python).  We also import some helper methods from `visualize.py` and `compare_vocabulary.py`.  These modules can be used via their commandline drivers as well if preferred (run `./visualize.py -h` and `./compare_vocabulary.py -h` for usage instructions).  Finally we also import some helper methods for rendering inline HTML within the notebook.

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=DeprecationWarning)
    warnings.simplefilter("ignore", category=ImportWarning)

    import os

    from visualize import visualize, color_key
    from compare_vocabulary import fdist, load_stopwords
    from rosette.api import API
    from IPython.display import display, HTML

# %% [markdown]
# ## Instantiating a Rosette API Instance
#
# The next step is to initialize Rosette API so that we can make API calls.  For this we need a Rosette API key.  If you already have a key or you want to sign up for a key, head over to [https://developer.rosette.com](https://developer.rosette.com).  After instantiating a `rosette.api.API` instance we also set the `output` URL parameter to `rosette` because we want to get detailed morphology analyses from Rosette's Annotated Data Model (ADM) in order to access the part-of-speech annotations.

# %%
api = API(
    user_key=(
        os.environ.get('ROSETTE_USER_KEY') or # load key from environment variable if possible
        getpass(prompt='Enter your Rosette API key: ') # fall back to prompting user for key
    ),
    service_url='https://api.rosette.com/rest/v1/'
)
api.setUrlParameter('output', 'rosette')

# %% [markdown]
# ## Decide which Part-of-Speech (POS) Tags to Include
#
# The next step is to determine which part-of-speech tags we are interested in comparing.  The less interesting tags have been commented out below, but you can experiment with different tags based on your interests.

# %%
POS_TAGS = {
    'ADJ',   #Adjective
    'ADP',   #Adposition
    'ADV',   #Adverb
    'AUX',   #Auxiliary
    'CONJ',  #Coordinating
    #'DET',   #Determiner
    'INTJ',  #Interjection
    'NOUN',  #Noun
    'NUM',   #Numeral
    #'PART',  #Particle
    'PRON',  #Pronoun
    'PROPN', #Proper
    #'PUNCT', #Punctuation
    'SCONJ', #Subordinating
    'SYM',   #Symbol
    'VERB',  #Verb
    'X',     #Other
}

# %% [markdown]
# ## Load Corpora from `data` Directories
#
# The following block identifies the directories `data/{carroll,frost,poe,shakespeare,whitman,yeats}` as corpora to analyze.  These directories comprise small collections of poems by famous poets.  You can add your own corpora to analyze simply by adding directories of plain-text `.txt` files to the `data` directory and replacing the directory names below.  We also pick a value for `n` here which determines the cut-off point to limit the frequency distributions to the top-n most frequent terms in the corpus.  If you want more results you can increase `n` and if you want to simply analyze the entire vocabulary you can set `n = None`.

# %%
corpora = 'carroll', 'frost', 'poe', 'shakespeare', 'whitman', 'yeats'
n = 100 # visualize frequencies for top n most frequent terms

# %% [markdown]
# ## Display Color Key
#
# To help interpret the color-coded part-of-speech tags for each term, a color key is rendered below.

# %%
display(HTML(color_key()))
# Out:
# <h2>Color Key</h2>
#     <table cellpadding="3" style="border-collapse:collapse">
#     <tr>
#         <th style="border: 1px solid; text-align: left">Tag</th>
#         <th style="border: 1px solid; text-align: left">Name</th>
#         <th style="border: 1px solid; text-align: left">Color</th>
#     </tr>
#     <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#4E8975">ADJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#4E8975">Adjective</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#4E8975">seagreen</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#A52A2A">ADP</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#A52A2A">Adposition</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#A52A2A">brown</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#32CD32">ADV</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#32CD32">Adverb</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#32CD32">limegreen</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#0000FF">AUX</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#0000FF">Auxiliary verb</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#0000FF">blue</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#ff4500">CONJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#ff4500">Coordinating conjunction</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#ff4500">orangered</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#c0c0c0">DET</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#c0c0c0">Determiner</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#c0c0c0">silver</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#493D26">INTJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#493D26">Interjection</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#493D26">mocha</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#FFA500">NOUN</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FFA500">Noun</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FFA500">orange</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#6698FF">NUM</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#6698FF">Numeral</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#6698FF">skyblue</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#FF00FF">PART</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF00FF">Particle</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF00FF">magenta</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#FF0000">PRON</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF0000">Pronoun</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF0000">red</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#8D38C9">PROPN</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#8D38C9">Proper noun</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#8D38C9">violet</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#008080">PUNCT</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#008080">Punctuation</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#008080">teal</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#EDDA74">SCONJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#EDDA74">Subordinating conjunction</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#EDDA74">goldenrod</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#808000">SYM</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#808000">Symbol</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#808000">olive</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#800080">VERB</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#800080">Verb</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#800080">purple</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#000000">X</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#000000">Other</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#000000">black</font>
#         </td>
#         </tr>
#         </table>

# %% [markdown]
# ## Visualize the Frequency Distributions
#
# The following code loops over each directory and computes a frequency distribution from the terms that occur in the corpus.  Note that the lemmas in each frequency distribution are filtered by an English stopword list.  Each term is then rendered with a color corresponding to its part-of-speech and its size is relative to its frequency.  You can hover your mouse over individual terms to see the numerical frequencies.

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", ResourceWarning)
    
    stopwords = load_stopwords('stopwords.json')['eng']
    
    for corpus in corpora:
        display(HTML(f'<h1>{corpus}</h1>'))
        fd = fdist(f'data/{corpus}', api, n, stopwords)
        display(HTML(visualize(fd, pos_tags=POS_TAGS)))
# Out:
# <h1>carroll</h1>
# <font
#             color="#800080"
#             size=24.0
#             title="say/VERB (23)"
#         >
#         say
#         </font>
# <font
#             color="#800080"
#             size=9.761904761904763
#             title="come/VERB (10)"
#         >
#         come
#         </font>
# <font
#             color="#8D38C9"
#             size=8.666666666666668
#             title="Walrus/PROPN (9)"
#         >
#         Walrus
#         </font>
# <font
#             color="#8D38C9"
#             size=6.476190476190476
#             title="Carpenter/PROPN (7)"
#         >
#         Carpenter
#         </font>
# <font
#             color="#800080"
#             size=6.476190476190476
#             title="give/VERB (7)"
#         >
#         give
#         </font>
# <font
#             color="#6698FF"
#             size=5.380952380952381
#             title="one/NUM (6)"
#         >
#         one
#         </font>
# <font
#             color="#FFA500"
#             size=5.380952380952381
#             title="youth/NOUN (6)"
#         >
#         youth
#         </font>
# <font
#             color="#8D38C9"
#             size=4.285714285714286
#             title="Oysters/PROPN (5)"
#         >
#         Oysters
#         </font>
# <font
#             color="#32CD32"
#             size=4.285714285714286
#             title="yet/ADV (5)"
#         >
#         yet
#         </font>
# <font
#             color="#FFA500"
#             size=3.1904761904761907
#             title="jaw/NOUN (4)"
#         >
#         jaw
#         </font>
# <font
#             color="#800080"
#             size=3.1904761904761907
#             title="stand/VERB (4)"
#         >
#         stand
#         </font>
# <font
#             color="#FFA500"
#             size=3.1904761904761907
#             title="eye/NOUN (4)"
#         >
#         eye
#         </font>
# <font
#             color="#800080"
#             size=3.1904761904761907
#             title="shine/VERB (4)"
#         >
#         shine
#         </font>
# <font
#             color="#4E8975"
#             size=3.1904761904761907
#             title="good/ADJ (4)"
#         >
#         good
#         </font>
# <font
#             color="#6698FF"
#             size=3.1904761904761907
#             title="four/NUM (4)"
#         >
#         four
#         </font>
# <font
#             color="#FFA500"
#             size=3.1904761904761907
#             title="oyster/NOUN (4)"
#         >
#         oyster
#         </font>
# <font
#             color="#4E8975"
#             size=3.1904761904761907
#             title="old/ADJ (4)"
#         >
#         old
#         </font>
# <font
#             color="#8D38C9"
#             size=2.0952380952380953
#             title="Jabberwock/PROPN (3)"
#         >
#         Jabberwock
#         </font>
# <font
#             color="#FFA500"
#             size=2.0952380952380953
#             title="bird/NOUN (3)"
#         >
#         bird
#         </font>
# <font
#             color="#FFA500"
#             size=2.0952380952380953
#             title="hand/NOUN (3)"
#         >
#         hand
#         </font>
# <font
#             color="#6698FF"
#             size=2.0952380952380953
#             title="two/NUM (3)"
#         >
#         two
#         </font>
# <font
#             color="#800080"
#             size=2.0952380952380953
#             title="go/VERB (3)"
#         >
#         go
#         </font>
# <font
#             color="#FFA500"
#             size=2.0952380952380953
#             title="head/NOUN (3)"
#         >
#         head
#         </font>
# <font
#             color="#8D38C9"
#             size=2.0952380952380953
#             title="o/PROPN (3)"
#         >
#         o
#         </font>
# <font
#             color="#FFA500"
#             size=2.0952380952380953
#             title="day/NOUN (3)"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             size=2.0952380952380953
#             title="sea/NOUN (3)"
#         >
#         sea
#         </font>
# <font
#             color="#800080"
#             size=2.0952380952380953
#             title="make/VERB (3)"
#         >
#         make
#         </font>
# <font
#             color="#4E8975"
#             size=2.0952380952380953
#             title="odd/ADJ (3)"
#         >
#         odd
#         </font>
# <font
#             color="#800080"
#             size=2.0952380952380953
#             title="think/VERB (3)"
#         >
#         think
#         </font>
# <font
#             color="#4E8975"
#             size=2.0952380952380953
#             title="pleasant/ADJ (3)"
#         >
#         pleasant
#         </font>
# <font
#             color="#800080"
#             size=2.0952380952380953
#             title="know/VERB (3)"
#         >
#         know
#         </font>
# <font
#             color="#4E8975"
#             size=2.0952380952380953
#             title="little/ADJ (3)"
#         >
#         little
#         </font>
# <font
#             color="#8D38C9"
#             size=2.0952380952380953
#             title="Father/PROPN (3)"
#         >
#         Father
#         </font>
# <font
#             color="#8D38C9"
#             size=2.0952380952380953
#             title="William/PROPN (3)"
#         >
#         William
#         </font>
# <font
#             color="#8D38C9"
#             size=1.0
#             title="Twas/PROPN (2)"
#         >
#         Twas
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="brillig/NOUN (2)"
#         >
#         brillig
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="slithy/ADJ (2)"
#         >
#         slithy
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="tove/NOUN (2)"
#         >
#         tove
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="gyre/ADJ (2)"
#         >
#         gyre
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="gimble/ADJ (2)"
#         >
#         gimble
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="mimsy/NOUN (2)"
#         >
#         mimsy
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="borogoves/NOUN (2)"
#         >
#         borogoves
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="mome/ADJ (2)"
#         >
#         mome
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="raths/ADJ (2)"
#         >
#         raths
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="outgrabe/NOUN (2)"
#         >
#         outgrabe
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="beware/VERB (2)"
#         >
#         beware
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="son/NOUN (2)"
#         >
#         son
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="claw/NOUN (2)"
#         >
#         claw
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="take/VERB (2)"
#         >
#         take
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="vorpal/ADJ (2)"
#         >
#         vorpal
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="time/NOUN (2)"
#         >
#         time
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="rest/VERB (2)"
#         >
#         rest
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="thought/NOUN (2)"
#         >
#         thought
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="leave/VERB (2)"
#         >
#         leave
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="sun/NOUN (2)"
#         >
#         sun
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="night/NOUN (2)"
#         >
#         night
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="get/VERB (2)"
#         >
#         get
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="wet/ADJ (2)"
#         >
#         wet
#         </font>
# <font
# <h1>frost</h1>
# <font
#             color="#800080"
#             size=24.0
#             title="go/VERB (11)"
#         >
#         go
#         </font>
# <font
#             color="#6698FF"
#             size=21.444444444444443
#             title="one/NUM (10)"
#         >
#         one
#         </font>
# <font
#             color="#800080"
#             size=21.444444444444443
#             title="make/VERB (10)"
#         >
#         make
#         </font>
# <font
#             color="#800080"
#             size=18.88888888888889
#             title="say/VERB (9)"
#         >
#         say
#         </font>
# <font
#             color="#FFA500"
#             size=16.333333333333336
#             title="wood/NOUN (8)"
#         >
#         wood
#         </font>
# <font
#             color="#4E8975"
#             size=13.777777777777779
#             title="good/ADJ (7)"
#         >
#         good
#         </font>
# <font
#             color="#FFA500"
#             size=13.777777777777779
#             title="tree/NOUN (7)"
#         >
#         tree
#         </font>
# <font
#             color="#800080"
#             size=11.222222222222221
#             title="think/VERB (6)"
#         >
#         think
#         </font>
# <font
#             color="#800080"
#             size=11.222222222222221
#             title="know/VERB (6)"
#         >
#         know
#         </font>
# <font
#             color="#800080"
#             size=11.222222222222221
#             title="see/VERB (6)"
#         >
#         see
#         </font>
# <font
#             color="#FFA500"
#             size=11.222222222222221
#             title="wall/NOUN (6)"
#         >
#         wall
#         </font>
# <font
#             color="#800080"
#             size=8.666666666666668
#             title="come/VERB (5)"
#         >
#         come
#         </font>
# <font
#             color="#FFA500"
#             size=8.666666666666668
#             title="birch/NOUN (5)"
#         >
#         birch
#         </font>
# <font
#             color="#FFA500"
#             size=8.666666666666668
#             title="ice/NOUN (5)"
#         >
#         ice
#         </font>
# <font
#             color="#0000FF"
#             size=6.111111111111111
#             title="will/AUX (4)"
#         >
#         will
#         </font>
# <font
#             color="#800080"
#             size=6.111111111111111
#             title="keep/VERB (4)"
#         >
#         keep
#         </font>
# <font
#             color="#800080"
#             size=6.111111111111111
#             title="take/VERB (4)"
#         >
#         take
#         </font>
# <font
#             color="#32CD32"
#             size=6.111111111111111
#             title="back/ADV (4)"
#         >
#         back
#         </font>
# <font
#             color="#800080"
#             size=6.111111111111111
#             title="do not/VERB (4)"
#         >
#         do not
#         </font>
# <font
#             color="#FFA500"
#             size=6.111111111111111
#             title="ground/NOUN (4)"
#         >
#         ground
#         </font>
# <font
#             color="#FFA500"
#             size=6.111111111111111
#             title="stone/NOUN (4)"
#         >
#         stone
#         </font>
# <font
#             color="#FFA500"
#             size=6.111111111111111
#             title="neighbor/NOUN (4)"
#         >
#         neighbor
#         </font>
# <font
#             color="#A52A2A"
#             size=6.111111111111111
#             title="across/ADP (4)"
#         >
#         across
#         </font>
# <font
#             color="#A52A2A"
#             size=6.111111111111111
#             title="like/ADP (4)"
#         >
#         like
#         </font>
# <font
#             color="#800080"
#             size=6.111111111111111
#             title="like/VERB (4)"
#         >
#         like
#         </font>
# <font
#             color="#800080"
#             size=6.111111111111111
#             title="break/VERB (4)"
#         >
#         break
#         </font>
# <font
#             color="#32CD32"
#             size=6.111111111111111
#             title="away/ADV (4)"
#         >
#         away
#         </font>
# <font
#             color="#800080"
#             size=3.5555555555555554
#             title="stop/VERB (3)"
#         >
#         stop
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="snow/NOUN (3)"
#         >
#         snow
#         </font>
# <font
#             color="#4E8975"
#             size=3.5555555555555554
#             title="dark/ADJ (3)"
#         >
#         dark
#         </font>
# <font
#             color="#6698FF"
#             size=3.5555555555555554
#             title="two/NUM (3)"
#         >
#         two
#         </font>
# <font
#             color="#800080"
#             size=3.5555555555555554
#             title="bend/VERB (3)"
#         >
#         bend
#         </font>
# <font
#             color="#4E8975"
#             size=3.5555555555555554
#             title="one/ADJ (3)"
#         >
#         one
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="day/NOUN (3)"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="way/NOUN (3)"
#         >
#         way
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="sun/NOUN (3)"
#         >
#         sun
#         </font>
# <font
#             color="#0000FF"
#             size=3.5555555555555554
#             title="can/AUX (3)"
#         >
#         can
#         </font>
# <font
#             color="#800080"
#             size=3.5555555555555554
#             title="leave/VERB (3)"
#         >
#         leave
#         </font>
# <font
#             color="#800080"
#             size=3.5555555555555554
#             title="stay/VERB (3)"
#         >
#         stay
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="cow/NOUN (3)"
#         >
#         cow
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="boy/NOUN (3)"
#         >
#         boy
#         </font>
# <font
#             color="#800080"
#             size=3.5555555555555554
#             title="learn/VERB (3)"
#         >
#         learn
#         </font>
# <font
#             color="#800080"
#             size=3.5555555555555554
#             title="climb/VERB (3)"
#         >
#         climb
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="fire/NOUN (3)"
#         >
#         fire
#         </font>
# <font
#             color="#FFA500"
#             size=3.5555555555555554
#             title="leaf/NOUN (3)"
#         >
#         leaf
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="fill/VERB (2)"
#         >
#         fill
#         </font>
# <font
#             color="#0000FF"
#             size=1.0
#             title="must/AUX (2)"
#         >
#         must
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="frozen/ADJ (2)"
#         >
#         frozen
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="year/NOUN (2)"
#         >
#         year
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="give/VERB (2)"
#         >
#         give
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="ask/VERB (2)"
#         >
#         ask
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="mile/NOUN (2)"
#         >
#         mile
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="sleep/VERB (2)"
#         >
#         sleep
#         </font>
# <font
#             color="#FFA500"
#             size=1.0
#             title="road/NOUN (2)"
#         >
#         road
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="diverge/VERB (2)"
#         >
#         diverge
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="travel/VERB (2)"
#         >
#         travel
#         </font>
# <font
#             color="#FF0000"
#             size=1.0
#             title="one/PRON (2)"
#         >
#         one
#         </font>
# <font
#             color="#32CD32"
#             size=1
# <h1>poe</h1>
# <font
#             color="#FF0000"
#             size=24.0
#             title="thou/PRON (15)"
#         >
#         thou
#         </font>
# <font
#             color="#FFA500"
#             size=22.083333333333332
#             title="door/NOUN (14)"
#         >
#         door
#         </font>
# <font
#             color="#FFA500"
#             size=22.083333333333332
#             title="sea/NOUN (14)"
#         >
#         sea
#         </font>
# <font
#             color="#A52A2A"
#             size=18.25
#             title="upon/ADP (12)"
#         >
#         upon
#         </font>
# <font
#             color="#FFA500"
#             size=18.25
#             title="soul/NOUN (12)"
#         >
#         soul
#         </font>
# <font
#             color="#32CD32"
#             size=18.25
#             title="nevermore/ADV (12)"
#         >
#         nevermore
#         </font>
# <font
#             color="#FFA500"
#             size=16.333333333333336
#             title="chamber/NOUN (11)"
#         >
#         chamber
#         </font>
# <font
#             color="#8D38C9"
#             size=16.333333333333336
#             title="Lenore/PROPN (11)"
#         >
#         Lenore
#         </font>
# <font
#             color="#FFA500"
#             size=14.416666666666666
#             title="bird/NOUN (10)"
#         >
#         bird
#         </font>
# <font
#             color="#FFA500"
#             size=12.5
#             title="raven/NOUN (9)"
#         >
#         raven
#         </font>
# <font
#             color="#FFA500"
#             size=12.5
#             title="eye/NOUN (9)"
#         >
#         eye
#         </font>
# <font
#             color="#800080"
#             size=12.5
#             title="lie/VERB (9)"
#         >
#         lie
#         </font>
# <font
#             color="#800080"
#             size=12.5
#             title="love/VERB (9)"
#         >
#         love
#         </font>
# <font
#             color="#FF0000"
#             size=10.583333333333334
#             title="nothing/PRON (8)"
#         >
#         nothing
#         </font>
# <font
#             color="#FFA500"
#             size=10.583333333333334
#             title="heart/NOUN (8)"
#         >
#         heart
#         </font>
# <font
#             color="#800080"
#             size=10.583333333333334
#             title="say/VERB (8)"
#         >
#         say
#         </font>
# <font
#             color="#32CD32"
#             size=10.583333333333334
#             title="still/ADV (8)"
#         >
#         still
#         </font>
# <font
#             color="#8D38C9"
#             size=10.583333333333334
#             title="Annabel/PROPN (8)"
#         >
#         Annabel
#         </font>
# <font
#             color="#8D38C9"
#             size=10.583333333333334
#             title="Lee/PROPN (8)"
#         >
#         Lee
#         </font>
# <font
#             color="#800080"
#             size=8.666666666666668
#             title="come/VERB (7)"
#         >
#         come
#         </font>
# <font
#             color="#FFA500"
#             size=8.666666666666668
#             title="angel/NOUN (7)"
#         >
#         angel
#         </font>
# <font
#             color="#32CD32"
#             size=8.666666666666668
#             title="now/ADV (7)"
#         >
#         now
#         </font>
# <font
#             color="#A52A2A"
#             size=8.666666666666668
#             title="within/ADP (7)"
#         >
#         within
#         </font>
# <font
#             color="#FFA500"
#             size=8.666666666666668
#             title="wind/NOUN (7)"
#         >
#         wind
#         </font>
# <font
#             color="#32CD32"
#             size=8.666666666666668
#             title="far/ADV (7)"
#         >
#         far
#         </font>
# <font
#             color="#0000FF"
#             size=8.666666666666668
#             title="shall/AUX (7)"
#         >
#         shall
#         </font>
# <font
#             color="#FFA500"
#             size=8.666666666666668
#             title="shadow/NOUN (7)"
#         >
#         shadow
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="die/VERB (6)"
#         >
#         die
#         </font>
# <font
#             color="#FFA500"
#             size=6.75
#             title="name/NOUN (6)"
#         >
#         name
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="let/VERB (6)"
#         >
#         let
#         </font>
# <font
#             color="#FFA500"
#             size=6.75
#             title="bust/NOUN (6)"
#         >
#         bust
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="sit/VERB (6)"
#         >
#         sit
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="tell/VERB (6)"
#         >
#         tell
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="leave/VERB (6)"
#         >
#         leave
#         </font>
# <font
#             color="#FFA500"
#             size=6.75
#             title="love/NOUN (6)"
#         >
#         love
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="tap/VERB (5)"
#         >
#         tap
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="maiden/NOUN (5)"
#         >
#         maiden
#         </font>
# <font
#             color="#32CD32"
#             size=4.833333333333334
#             title="never/ADV (5)"
#         >
#         never
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="feel/VERB (5)"
#         >
#         feel
#         </font>
# <font
#             color="#32CD32"
#             size=4.833333333333334
#             title="ever/ADV (5)"
#         >
#         ever
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="word/NOUN (5)"
#         >
#         word
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="see/VERB (5)"
#         >
#         see
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="quoth/VERB (5)"
#         >
#         quoth
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="fly/VERB (5)"
#         >
#         fly
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="light/NOUN (5)"
#         >
#         light
#         </font>
# <font
#             color="#A52A2A"
#             size=4.833333333333334
#             title="o'er/ADP (5)"
#         >
#         o'er
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="kingdom/NOUN (5)"
#         >
#         kingdom
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="heaven/NOUN (5)"
#         >
#         heaven
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="life/NOUN (5)"
#         >
#         life
#         </font>
# <font
#             color="#8D38C9"
#             size=4.833333333333334
#             title="Eldorado/PROPN (5)"
#         >
#         Eldorado
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="stone/NOUN (5)"
#         >
#         stone
#         </font>
# <font
#             color="#800080"
#             size=2.916666666666667
#             title="forget/VERB (4)"
#         >
#         forget
#         </font>
# <font
#             color="#493D26"
#             size=2.916666666666667
#             title="ah/INTJ (4)"
#         >
#         ah
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="floor/NOUN (4)"
#         >
#         floor
#         </font>
# <font
#             color="#800080"
#             size=2.916666666666667
#             title="seek/VERB (4)"
#         >
#         seek
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="sorrow/NOUN (4)"
#         >
#         sorrow
#         </font>
# <font
#             color="#4E8975"
#             size=2.916666666666667
#             title="sad/ADJ (4)"
#         >
#         sad
#         </font>
# <font
#             color="#32CD32"
# <h1>shakespeare</h1>
# <font
#             color="#FF0000"
#             size=24.0
#             title="thou/PRON (12)"
#         >
#         thou
#         </font>
# <font
#             color="#0000FF"
#             size=17.727272727272727
#             title="shall/AUX (9)"
#         >
#         shall
#         </font>
# <font
#             color="#FFA500"
#             size=15.636363636363637
#             title="love/NOUN (8)"
#         >
#         love
#         </font>
# <font
#             color="#FFA500"
#             size=13.545454545454545
#             title="sonnet/NOUN (7)"
#         >
#         sonnet
#         </font>
# <font
#             color="#FFA500"
#             size=11.454545454545455
#             title="eye/NOUN (6)"
#         >
#         eye
#         </font>
# <font
#             color="#FFA500"
#             size=9.363636363636363
#             title="time/NOUN (5)"
#         >
#         time
#         </font>
# <font
#             color="#32CD32"
#             size=7.2727272727272725
#             title="long/ADV (4)"
#         >
#         long
#         </font>
# <font
#             color="#0000FF"
#             size=7.2727272727272725
#             title="can/AUX (4)"
#         >
#         can
#         </font>
# <font
#             color="#800080"
#             size=7.2727272727272725
#             title="see/VERB (4)"
#         >
#         see
#         </font>
# <font
#             color="#FFA500"
#             size=7.2727272727272725
#             title="woe/NOUN (4)"
#         >
#         woe
#         </font>
# <font
#             color="#FFA500"
#             size=7.2727272727272725
#             title="death/NOUN (4)"
#         >
#         death
#         </font>
# <font
#             color="#FFA500"
#             size=5.181818181818182
#             title="summer/NOUN (3)"
#         >
#         summer
#         </font>
# <font
#             color="#800080"
#             size=5.181818181818182
#             title="shake/VERB (3)"
#         >
#         shake
#         </font>
# <font
#             color="#800080"
#             size=5.181818181818182
#             title="love/VERB (3)"
#         >
#         love
#         </font>
# <font
#             color="#32CD32"
#             size=5.181818181818182
#             title="never/ADV (3)"
#         >
#         never
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="day/NOUN (2)"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="art/NOUN (2)"
#         >
#         art
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="hath/ADJ (2)"
#         >
#         hath
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="heaven/NOUN (2)"
#         >
#         heaven
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="fair/ADJ (2)"
#         >
#         fair
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="eternal/ADJ (2)"
#         >
#         eternal
#         </font>
# <font
#             color="#8D38C9"
#             size=3.090909090909091
#             title="Death/PROPN (2)"
#         >
#         Death
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="man/NOUN (2)"
#         >
#         man
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="live/VERB (2)"
#         >
#         live
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="sweet/ADJ (2)"
#         >
#         sweet
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="thing/NOUN (2)"
#         >
#         thing
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="new/ADJ (2)"
#         >
#         new
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="dear/ADJ (2)"
#         >
#         dear
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="friend/NOUN (2)"
#         >
#         friend
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="night/NOUN (2)"
#         >
#         night
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="pay/VERB (2)"
#         >
#         pay
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="think/VERB (2)"
#         >
#         think
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="gilded/ADJ (2)"
#         >
#         gilded
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="war/NOUN (2)"
#         >
#         war
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="fire/NOUN (2)"
#         >
#         fire
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="find/VERB (2)"
#         >
#         find
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="doom/NOUN (2)"
#         >
#         doom
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="tired/ADJ (2)"
#         >
#         tired
#         </font>
# <font
#             color="#FF0000"
#             size=3.090909090909091
#             title="nothing/PRON (2)"
#         >
#         nothing
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="make/VERB (2)"
#         >
#         make
#         </font>
# <font
#             color="#A52A2A"
#             size=3.090909090909091
#             title="like/ADP (2)"
#         >
#         like
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="go/VERB (2)"
#         >
#         go
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="leave/VERB (2)"
#         >
#         leave
#         </font>
# <font
#             color="#A52A2A"
#             size=3.090909090909091
#             title="upon/ADP (2)"
#         >
#         upon
#         </font>
# <font
#             color="#8D38C9"
#             size=3.090909090909091
#             title="see'st/PROPN (2)"
#         >
#         see'st
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="black/ADJ (2)"
#         >
#         black
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="doth/NOUN (2)"
#         >
#         doth
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="take/VERB (2)"
#         >
#         take
#         </font>
# <font
#             color="#0000FF"
#             size=3.090909090909091
#             title="must/AUX (2)"
#         >
#         must
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="alter/VERB (2)"
#         >
#         alter
#         </font>
# <font
#             color="#800080"
#             size=3.090909090909091
#             title="bend/VERB (2)"
#         >
#         bend
#         </font>
# <font
#             color="#32CD32"
#             size=3.090909090909091
#             title="ever/ADV (2)"
#         >
#         ever
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="lip/NOUN (2)"
#         >
#         lip
#         </font>
# <font
#             color="#FFA500"
#             size=3.090909090909091
#             title="cheek/NOUN (2)"
#         >
#         cheek
#         </font>
# <font
#             color="#32CD32"
#             size=3.090909090909091
#             title="far/ADV (2)"
#         >
#         far
#         </font>
# <font
#             color="#4E8975"
#             size=3.090909090909091
#             title="red/ADJ (2)"
#         >
#         red
#         </font>
# <font
#             color="#4E8975"
# <h1>whitman</h1>
# <font
#             color="#8D38C9"
#             size=24.0
#             title="o/PROPN (13)"
#         >
#         o
#         </font>
# <font
#             color="#800080"
#             size=12.5
#             title="sing/VERB (7)"
#         >
#         sing
#         </font>
# <font
#             color="#6698FF"
#             size=10.583333333333334
#             title="one/NUM (6)"
#         >
#         one
#         </font>
# <font
#             color="#32CD32"
#             size=10.583333333333334
#             title="alone/ADV (6)"
#         >
#         alone
#         </font>
# <font
#             color="#FFA500"
#             size=10.583333333333334
#             title="love/NOUN (6)"
#         >
#         love
#         </font>
# <font
#             color="#FFA500"
#             size=8.666666666666668
#             title="book/NOUN (5)"
#         >
#         book
#         </font>
# <font
#             color="#800080"
#             size=8.666666666666668
#             title="make/VERB (5)"
#         >
#         make
#         </font>
# <font
#             color="#FFA500"
#             size=8.666666666666668
#             title="hour/NOUN (5)"
#         >
#         hour
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="utter/VERB (4)"
#         >
#         utter
#         </font>
# <font
#             color="#FFA500"
#             size=6.75
#             title="life/NOUN (4)"
#         >
#         life
#         </font>
# <font
#             color="#FFA500"
#             size=6.75
#             title="joy/NOUN (4)"
#         >
#         joy
#         </font>
# <font
#             color="#FFA500"
#             size=6.75
#             title="day/NOUN (4)"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             size=6.75
#             title="ocean/NOUN (4)"
#         >
#         ocean
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="know/VERB (4)"
#         >
#         know
#         </font>
# <font
#             color="#800080"
#             size=6.75
#             title="think/VERB (4)"
#         >
#         think
#         </font>
# <font
#             color="#32CD32"
#             size=4.833333333333334
#             title="yet/ADV (3)"
#         >
#         yet
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="word/NOUN (3)"
#         >
#         word
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="form/NOUN (3)"
#         >
#         form
#         </font>
# <font
#             color="#4E8975"
#             size=4.833333333333334
#             title="free/ADJ (3)"
#         >
#         free
#         </font>
# <font
#             color="#4E8975"
#             size=4.833333333333334
#             title="one/ADJ (3)"
#         >
#         one
#         </font>
# <font
#             color="#32CD32"
#             size=4.833333333333334
#             title="much/ADV (3)"
#         >
#         much
#         </font>
# <font
#             color="#0000FF"
#             size=4.833333333333334
#             title="will/AUX (3)"
#         >
#         will
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="space/NOUN (3)"
#         >
#         space
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="love/VERB (3)"
#         >
#         love
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="lose/VERB (3)"
#         >
#         lose
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="look/VERB (3)"
#         >
#         look
#         </font>
# <font
#             color="#8D38C9"
#             size=4.833333333333334
#             title="City/PROPN (3)"
#         >
#         City
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="repay/VERB (3)"
#         >
#         repay
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="lover/NOUN (3)"
#         >
#         lover
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="see/VERB (3)"
#         >
#         see
#         </font>
# <font
#             color="#8D38C9"
#             size=4.833333333333334
#             title="Louisiana/PROPN (3)"
#         >
#         Louisiana
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="grow/VERB (3)"
#         >
#         grow
#         </font>
# <font
#             color="#A52A2A"
#             size=4.833333333333334
#             title="without/ADP (3)"
#         >
#         without
#         </font>
# <font
#             color="#4E8975"
#             size=4.833333333333334
#             title="joyous/ADJ (3)"
#         >
#         joyous
#         </font>
# <font
#             color="#FFA500"
#             size=4.833333333333334
#             title="friend/NOUN (3)"
#         >
#         friend
#         </font>
# <font
#             color="#800080"
#             size=4.833333333333334
#             title="leave/VERB (3)"
#         >
#         leave
#         </font>
# <font
#             color="#FF0000"
#             size=2.916666666666667
#             title="one/PRON (2)"
#         >
#         one
#         </font>
# <font
#             color="#4E8975"
#             size=2.916666666666667
#             title="separate/ADJ (2)"
#         >
#         separate
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="person/NOUN (2)"
#         >
#         person
#         </font>
# <font
#             color="#4E8975"
#             size=2.916666666666667
#             title="worthy/ADJ (2)"
#         >
#         worthy
#         </font>
# <font
#             color="#800080"
#             size=2.916666666666667
#             title="say/VERB (2)"
#         >
#         say
#         </font>
# <font
#             color="#32CD32"
#             size=2.916666666666667
#             title="far/ADV (2)"
#         >
#         far
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="power/NOUN (2)"
#         >
#         power
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="step/NOUN (2)"
#         >
#         step
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="plea/NOUN (2)"
#         >
#         plea
#         </font>
# <font
#             color="#32CD32"
#             size=2.916666666666667
#             title="hardly/ADV (2)"
#         >
#         hardly
#         </font>
# <font
#             color="#800080"
#             size=2.916666666666667
#             title="go/VERB (2)"
#         >
#         go
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="time/NOUN (2)"
#         >
#         time
#         </font>
# <font
#             color="#800080"
#             size=2.916666666666667
#             title="besiege/VERB (2)"
#         >
#         besiege
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="place/NOUN (2)"
#         >
#         place
#         </font>
# <font
#             color="#4E8975"
#             size=2.916666666666667
#             title="swift/ADJ (2)"
#         >
#         swift
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="artillery/NOUN (2)"
#         >
#         artillery
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="man/NOUN (2)"
#         >
#         man
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="library/NOUN (2)"
#         >
#         library
#         </font>
# <font
#             color="#FFA500"
#             size=2.916666666666667
#             title="shelf/NOUN (2)"
#         >
#         shelf
#         </font>
# <font
#             color="#800080"
#             size=2.916666666666667
#             title="need/VERB (2)"
#         >
#         need
#         </font>
# <font
#             color="#800080"
#             size=2.916666666666667
#             title="bring/VERB (2)"
# <h1>yeats</h1>
# <font
#             color="#FFA500"
#             size=24.0
#             title="heart/NOUN (15)"
#         >
#         heart
#         </font>
# <font
#             color="#32CD32"
#             size=13.384615384615385
#             title="now/ADV (9)"
#         >
#         now
#         </font>
# <font
#             color="#0000FF"
#             size=11.615384615384615
#             title="will/AUX (8)"
#         >
#         will
#         </font>
# <font
#             color="#800080"
#             size=11.615384615384615
#             title="go/VERB (8)"
#         >
#         go
#         </font>
# <font
#             color="#800080"
#             size=11.615384615384615
#             title="make/VERB (8)"
#         >
#         make
#         </font>
# <font
#             color="#8D38C9"
#             size=11.615384615384615
#             title="o/PROPN (8)"
#         >
#         o
#         </font>
# <font
#             color="#A52A2A"
#             size=11.615384615384615
#             title="upon/ADP (8)"
#         >
#         upon
#         </font>
# <font
#             color="#800080"
#             size=9.846153846153847
#             title="come/VERB (7)"
#         >
#         come
#         </font>
# <font
#             color="#FFA500"
#             size=8.076923076923077
#             title="man/NOUN (6)"
#         >
#         man
#         </font>
# <font
#             color="#800080"
#             size=8.076923076923077
#             title="know/VERB (6)"
#         >
#         know
#         </font>
# <font
#             color="#800080"
#             size=8.076923076923077
#             title="give/VERB (6)"
#         >
#         give
#         </font>
# <font
#             color="#FFA500"
#             size=6.3076923076923075
#             title="peace/NOUN (5)"
#         >
#         peace
#         </font>
# <font
#             color="#FFA500"
#             size=6.3076923076923075
#             title="eye/NOUN (5)"
#         >
#         eye
#         </font>
# <font
#             color="#800080"
#             size=6.3076923076923075
#             title="seem/VERB (5)"
#         >
#         seem
#         </font>
# <font
#             color="#800080"
#             size=6.3076923076923075
#             title="burn/VERB (5)"
#         >
#         burn
#         </font>
# <font
#             color="#FFA500"
#             size=6.3076923076923075
#             title="beauty/NOUN (5)"
#         >
#         beauty
#         </font>
# <font
#             color="#0000FF"
#             size=6.3076923076923075
#             title="can/AUX (5)"
#         >
#         can
#         </font>
# <font
#             color="#FFA500"
#             size=4.538461538461538
#             title="day/NOUN (4)"
#         >
#         day
#         </font>
# <font
#             color="#800080"
#             size=4.538461538461538
#             title="hear/VERB (4)"
#         >
#         hear
#         </font>
# <font
#             color="#FFA500"
#             size=4.538461538461538
#             title="water/NOUN (4)"
#         >
#         water
#         </font>
# <font
#             color="#4E8975"
#             size=4.538461538461538
#             title="old/ADJ (4)"
#         >
#         old
#         </font>
# <font
#             color="#A52A2A"
#             size=4.538461538461538
#             title="like/ADP (4)"
#         >
#         like
#         </font>
# <font
#             color="#FFA500"
#             size=4.538461538461538
#             title="thing/NOUN (4)"
#         >
#         thing
#         </font>
# <font
#             color="#FFA500"
#             size=4.538461538461538
#             title="head/NOUN (4)"
#         >
#         head
#         </font>
# <font
#             color="#800080"
#             size=4.538461538461538
#             title="bring/VERB (4)"
#         >
#         bring
#         </font>
# <font
#             color="#800080"
#             size=4.538461538461538
#             title="say/VERB (4)"
#         >
#         say
#         </font>
# <font
#             color="#32CD32"
#             size=4.538461538461538
#             title="never/ADV (4)"
#         >
#         never
#         </font>
# <font
#             color="#800080"
#             size=4.538461538461538
#             title="dream/VERB (4)"
#         >
#         dream
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="wing/NOUN (3)"
#         >
#         wing
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="blood/NOUN (3)"
#         >
#         blood
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="crowd/NOUN (3)"
#         >
#         crowd
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="face/NOUN (3)"
#         >
#         face
#         </font>
# <font
#             color="#800080"
#             size=2.769230769230769
#             title="grow/VERB (3)"
#         >
#         grow
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="hand/NOUN (3)"
#         >
#         hand
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="cloud/NOUN (3)"
#         >
#         cloud
#         </font>
# <font
#             color="#A52A2A"
#             size=2.769230769230769
#             title="among/ADP (3)"
#         >
#         among
#         </font>
# <font
#             color="#4E8975"
#             size=2.769230769230769
#             title="great/ADJ (3)"
#         >
#         great
#         </font>
# <font
#             color="#32CD32"
#             size=2.769230769230769
#             title="still/ADV (3)"
#         >
#         still
#         </font>
# <font
#             color="#4E8975"
#             size=2.769230769230769
#             title="young/ADJ (3)"
#         >
#         young
#         </font>
# <font
#             color="#0000FF"
#             size=2.769230769230769
#             title="can not/AUX (3)"
#         >
#         can not
#         </font>
# <font
#             color="#8D38C9"
#             size=2.769230769230769
#             title="Second/PROPN (3)"
#         >
#         Second
#         </font>
# <font
#             color="#8D38C9"
#             size=2.769230769230769
#             title="Coming/PROPN (3)"
#         >
#         Coming
#         </font>
# <font
#             color="#800080"
#             size=2.769230769230769
#             title="turn/VERB (3)"
#         >
#         turn
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="lion/NOUN (3)"
#         >
#         lion
#         </font>
# <font
#             color="#8D38C9"
#             size=2.769230769230769
#             title="Time/PROPN (3)"
#         >
#         Time
#         </font>
# <font
#             color="#FFA500"
#             size=2.769230769230769
#             title="form/NOUN (3)"
#         >
#         form
#         </font>
# <font
#             color="#800080"
#             size=2.769230769230769
#             title="breed/VERB (3)"
#         >
#         breed
#         </font>
# <font
#             color="#A52A2A"
#             size=2.769230769230769
#             title="amid/ADP (3)"
#         >
#         amid
#         </font>
# <font
#             color="#8D38C9"
#             size=1.0
#             title="Innisfree/PROPN (2)"
#         >
#         Innisfree
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="arise/VERB (2)"
#         >
#         arise
#         </font>
# <font
#             color="#6698FF"
#             size=1.0
#             title="nine/NUM (2)"
#         >
#         nine
#         </font>
# <font
#             color="#32CD32"
#             size=1.0
#             title="alone/ADV (2)"
#         >
#         alone
#         </font>
# <font
#             color="#0000FF"
#             size=1.0
#             title="shall/AUX (2)"
#         >
#         shall
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="drop/VERB (2)"
#         >
#         drop
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="slow/ADJ (2)"
#         >
#         slow
#         </font>
# <font
#             color="#800080"
#             size=1.0
#             title="sing/VERB (2)"
#         >
#         sing
#         </font>
# <font
#             color="#4E8975"
#             size=1.0
#             title="full/ADJ (2)"
#         >
#         full
#         </font>
# <font
