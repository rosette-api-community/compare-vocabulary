# %% [markdown]
# # Visualize Term Frequency Distributions
#
# This notebook demonstrates how to visualize term frequency distributions using Rosette API via the `/morphology/lemmas` endpoint.  You can check out the code on [GitHub](https://github.com/rosette-api-community/compare-vocabulary/blob/master/README.md).
#
# ## Setup
#
# The first section imports the [Rosette API Python binding module](https://github.com/rosette-api/python).  We also import some helper methods from `visualize.py` and `compare_vocabulary.py`.  These modules can be used via their commandline drivers as well if preferred (run `./visualize.py -h` and `./compare_vocabulary.py -h` for usage instructions).  Finally we also import some helper methods for rendering inline HTML within the notebook.

# %%
import os

from visualize import visualize, color_key
from compare_vocabulary import fdist, load_stopwords
from rosette.api import API
from IPython.display import display, HTML

# %% [markdown]
# ## Instantiating a Rosette API Instance
#
# The next step is to initialize Rosette API so that we can make API calls.  For this we need a Rosette API key.  If you already have a key or you want to sign up for a key, head over to [https://developer.rosette.com](https://developer.rosette.com).  After instantiating a `rosette.api.API` instance we also set the `output` URL parameter to `rosette` because we want to get detailed morphology analyses from Rosette's Annotated Data Model (ADM) in order to access the part-of-speech annotations.

# %%
api = API(
    user_key=(
        os.environ.get('ROSETTE_USER_KEY') or # load key from environment variable if possible
        getpass(prompt='Enter your Rosette API key: ') # fall back to prompting user for key
    ),
    service_url='https://api.rosette.com/rest/v1/'
)
api.set_url_parameter('output', 'rosette')

# %% [markdown]
# ## Decide which Part-of-Speech (POS) Tags to Include
#
# The next step is to determine which part-of-speech tags we are interested in comparing.  The less interesting tags have been commented out below, but you can experiment with different tags based on your interests.

# %%
POS_TAGS = {
    'ADJ',   #Adjective
    'ADP',   #Adposition
    'ADV',   #Adverb
    'AUX',   #Auxiliary
    'CONJ',  #Coordinating
    #'DET',   #Determiner
    'INTJ',  #Interjection
    'NOUN',  #Noun
    'NUM',   #Numeral
    #'PART',  #Particle
    'PRON',  #Pronoun
    'PROPN', #Proper
    #'PUNCT', #Punctuation
    'SCONJ', #Subordinating
    'SYM',   #Symbol
    'VERB',  #Verb
    'X',     #Other
}

# %% [markdown]
# ## Load Corpora from `data` Directories
#
# The following block identifies the directories `data/{carroll,frost,poe,shakespeare,whitman,yeats}` as corpora to analyze.  These directories comprise small collections of poems by famous poets.  You can add your own corpora to analyze simply by adding directories of plain-text `.txt` files to the `data` directory and replacing the directory names below.  We also pick a value for `n` here which determines the cut-off point to limit the frequency distributions to the top-n most frequent terms in the corpus.  If you want more results you can increase `n` and if you want to simply analyze the entire vocabulary you can set `n = None`.

# %%
corpora = 'carroll', 'frost', 'poe', 'shakespeare', 'whitman', 'yeats'
n = 100 # visualize frequencies for top n most frequent terms

# %% [markdown]
# ## Display Color Key
#
# To help interpret the color-coded part-of-speech tags for each term, a color key is rendered below.

# %%
display(HTML(color_key()))
# Out:
# <h2>Color Key</h2>
#     <table cellpadding="3" style="border-collapse:collapse">
#     <tr>
#         <th style="border: 1px solid; text-align: left">Tag</th>
#         <th style="border: 1px solid; text-align: left">Name</th>
#         <th style="border: 1px solid; text-align: left">Color</th>
#     </tr>
#     <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#4E8975">ADJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#4E8975">Adjective</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#4E8975">seagreen</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#A52A2A">ADP</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#A52A2A">Adposition</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#A52A2A">brown</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#32CD32">ADV</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#32CD32">Adverb</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#32CD32">limegreen</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#0000FF">AUX</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#0000FF">Auxiliary verb</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#0000FF">blue</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#ff4500">CONJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#ff4500">Coordinating conjunction</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#ff4500">orangered</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#c0c0c0">DET</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#c0c0c0">Determiner</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#c0c0c0">silver</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#493D26">INTJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#493D26">Interjection</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#493D26">mocha</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#FFA500">NOUN</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FFA500">Noun</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FFA500">orange</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#6698FF">NUM</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#6698FF">Numeral</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#6698FF">skyblue</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#FF00FF">PART</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF00FF">Particle</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF00FF">magenta</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#FF0000">PRON</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF0000">Pronoun</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#FF0000">red</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#8D38C9">PROPN</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#8D38C9">Proper noun</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#8D38C9">violet</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#008080">PUNCT</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#008080">Punctuation</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#008080">teal</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#EDDA74">SCONJ</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#EDDA74">Subordinating conjunction</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#EDDA74">goldenrod</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#808000">SYM</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#808000">Symbol</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#808000">olive</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#800080">VERB</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#800080">Verb</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#800080">purple</font>
#         </td>
#         </tr>
#
# <tr style="border: 1px solid">
#         <td style="border: 1px solid">
#             <font color="#000000">X</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#000000">Other</font>
#         </td>
#         <td style="border: 1px solid">
#             <font color="#000000">black</font>
#         </td>
#         </tr>
#         </table>

# %% [markdown]
# ## Visualize the Frequency Distributions
#
# The following code loops over each directory and computes a frequency distribution from the terms that occur in the corpus.  Note that the lemmas in each frequency distribution are filtered by an English stopword list.  Each term is then rendered with a color corresponding to its part-of-speech and its size is relative to its frequency.  You can hover your mouse over individual terms to see the numerical frequencies.

# %%
stopwords = load_stopwords('stopwords.json')['eng']
    
for corpus in corpora:
    display(HTML(f'<h1>{corpus}</h1>'))
    fd = fdist(f'data/{corpus}', api, n, stopwords)
    display(HTML(visualize(fd, pos_tags=POS_TAGS)))
# Out:
# <h1>carroll</h1>
# <font
#             color="#800080"
#             title="say/VERB (23)"
#             style="font-size: 350.0%"
#         >
#         say
#         </font>
# <font
#             color="#800080"
#             title="come/VERB (10)"
#             style="font-size: 179.76190476190476%"
#         >
#         come
#         </font>
# <font
#             color="#8D38C9"
#             title="Walrus/PROPN (9)"
#             style="font-size: 166.66666666666669%"
#         >
#         Walrus
#         </font>
# <font
#             color="#800080"
#             title="give/VERB (7)"
#             style="font-size: 140.47619047619048%"
#         >
#         give
#         </font>
# <font
#             color="#8D38C9"
#             title="Carpenter/PROPN (7)"
#             style="font-size: 140.47619047619048%"
#         >
#         Carpenter
#         </font>
# <font
#             color="#FFA500"
#             title="youth/NOUN (6)"
#             style="font-size: 127.38095238095238%"
#         >
#         youth
#         </font>
# <font
#             color="#FFA500"
#             title="oyster/NOUN (6)"
#             style="font-size: 127.38095238095238%"
#         >
#         oyster
#         </font>
# <font
#             color="#6698FF"
#             title="one/NUM (5)"
#             style="font-size: 114.28571428571428%"
#         >
#         one
#         </font>
# <font
#             color="#4E8975"
#             title="little/ADJ (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         little
#         </font>
# <font
#             color="#800080"
#             title="shine/VERB (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         shine
#         </font>
# <font
#             color="#FFA500"
#             title="jaw/NOUN (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         jaw
#         </font>
# <font
#             color="#4E8975"
#             title="old/ADJ (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         old
#         </font>
# <font
#             color="#800080"
#             title="stand/VERB (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         stand
#         </font>
# <font
#             color="#FFA500"
#             title="eye/NOUN (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         eye
#         </font>
# <font
#             color="#4E8975"
#             title="good/ADJ (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         good
#         </font>
# <font
#             color="#8D38C9"
#             title="Oysters/PROPN (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         Oysters
#         </font>
# <font
#             color="#6698FF"
#             title="four/NUM (4)"
#             style="font-size: 101.19047619047619%"
#         >
#         four
#         </font>
# <font
#             color="#8D38C9"
#             title="Father/PROPN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         Father
#         </font>
# <font
#             color="#8D38C9"
#             title="William/PROPN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         William
#         </font>
# <font
#             color="#FFA500"
#             title="head/NOUN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         head
#         </font>
# <font
#             color="#800080"
#             title="think/VERB (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         think
#         </font>
# <font
#             color="#ff4500"
#             title="yet/CONJ (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         yet
#         </font>
# <font
#             color="#800080"
#             title="make/VERB (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         make
#         </font>
# <font
#             color="#FFA500"
#             title="day/NOUN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             title="sea/NOUN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         sea
#         </font>
# <font
#             color="#4E8975"
#             title="odd/ADJ (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         odd
#         </font>
# <font
#             color="#FFA500"
#             title="bird/NOUN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         bird
#         </font>
# <font
#             color="#FFA500"
#             title="hand/NOUN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         hand
#         </font>
# <font
#             color="#4E8975"
#             title="pleasant/ADJ (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         pleasant
#         </font>
# <font
#             color="#800080"
#             title="know/VERB (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         know
#         </font>
# <font
#             color="#8D38C9"
#             title="Jabberwock/PROPN (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         Jabberwock
#         </font>
# <font
#             color="#6698FF"
#             title="two/NUM (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         two
#         </font>
# <font
#             color="#800080"
#             title="go/VERB (3)"
#             style="font-size: 88.0952380952381%"
#         >
#         go
#         </font>
# <font
#             color="#800080"
#             title="seem/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         seem
#         </font>
# <font
#             color="#FFA500"
#             title="claw/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         claw
#         </font>
# <font
#             color="#4E8975"
#             title="young/ADJ (2)"
#             style="font-size: 75.0%"
#         >
#         young
#         </font>
# <font
#             color="#800080"
#             title="become/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         become
#         </font>
# <font
#             color="#32CD32"
#             title="yet/ADV (2)"
#             style="font-size: 75.0%"
#         >
#         yet
#         </font>
# <font
#             color="#FFA500"
#             title="son/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         son
#         </font>
# <font
#             color="#0000FF"
#             title="might/AUX (2)"
#             style="font-size: 75.0%"
#         >
#         might
#         </font>
# <font
#             color="#32CD32"
#             title="now/ADV (2)"
#             style="font-size: 75.0%"
#         >
#         now
#         </font>
# <font
#             color="#FF0000"
#             title="none/PRON (2)"
#             style="font-size: 75.0%"
#         >
#         none
#         </font>
# <font
#             color="#800080"
#             title="mention/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         mention
#         </font>
# <font
#             color="#4E8975"
#             title="fat/ADJ (2)"
#             style="font-size: 75.0%"
#         >
#         fat
#         </font>
# <font
#             color="#800080"
#             title="turn/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         turn
#         </font>
# <font
#             color="#800080"
#             title="pray/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         pray
#         </font>
# <font
#             color="#800080"
#             title="shake/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         shake
#         </font>
# <font
#             color="#800080"
#             title="keep/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         keep
#         </font>
# <font
#             color="#FF0000"
#             title="anything/PRON (2)"
#             style="font-size: 75.0%"
#         >
#         anything
#         </font>
# <font
#             color="#FFA500"
#             title="father/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         father
#         </font>
# <font
#             color="#800080"
#             title="take/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         take
#         </font>
# <font
#             color="#FFA500"
#             title="rest/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         rest
#         </font>
# <font
#             color="#800080"
# <h1>frost</h1>
# <font
#             color="#6698FF"
#             title="one/NUM (11)"
#             style="font-size: 350.0%"
#         >
#         one
#         </font>
# <font
#             color="#800080"
#             title="go/VERB (10)"
#             style="font-size: 319.44444444444446%"
#         >
#         go
#         </font>
# <font
#             color="#800080"
#             title="make/VERB (10)"
#             style="font-size: 319.44444444444446%"
#         >
#         make
#         </font>
# <font
#             color="#FFA500"
#             title="wood/NOUN (9)"
#             style="font-size: 288.8888888888889%"
#         >
#         wood
#         </font>
# <font
#             color="#800080"
#             title="say/VERB (8)"
#             style="font-size: 258.33333333333337%"
#         >
#         say
#         </font>
# <font
#             color="#FFA500"
#             title="tree/NOUN (7)"
#             style="font-size: 227.77777777777777%"
#         >
#         tree
#         </font>
# <font
#             color="#4E8975"
#             title="good/ADJ (7)"
#             style="font-size: 227.77777777777777%"
#         >
#         good
#         </font>
# <font
#             color="#800080"
#             title="know/VERB (6)"
#             style="font-size: 197.22222222222223%"
#         >
#         know
#         </font>
# <font
#             color="#800080"
#             title="see/VERB (6)"
#             style="font-size: 197.22222222222223%"
#         >
#         see
#         </font>
# <font
#             color="#FFA500"
#             title="wall/NOUN (6)"
#             style="font-size: 197.22222222222223%"
#         >
#         wall
#         </font>
# <font
#             color="#FFA500"
#             title="ice/NOUN (5)"
#             style="font-size: 166.66666666666669%"
#         >
#         ice
#         </font>
# <font
#             color="#800080"
#             title="think/VERB (5)"
#             style="font-size: 166.66666666666669%"
#         >
#         think
#         </font>
# <font
#             color="#FFA500"
#             title="birch/NOUN (5)"
#             style="font-size: 166.66666666666669%"
#         >
#         birch
#         </font>
# <font
#             color="#800080"
#             title="come/VERB (5)"
#             style="font-size: 166.66666666666669%"
#         >
#         come
#         </font>
# <font
#             color="#FFA500"
#             title="leaf/NOUN (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         leaf
#         </font>
# <font
#             color="#0000FF"
#             title="will/AUX (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         will
#         </font>
# <font
#             color="#A52A2A"
#             title="across/ADP (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         across
#         </font>
# <font
#             color="#800080"
#             title="like/VERB (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         like
#         </font>
# <font
#             color="#800080"
#             title="do not/VERB (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         do not
#         </font>
# <font
#             color="#32CD32"
#             title="away/ADV (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         away
#         </font>
# <font
#             color="#FFA500"
#             title="ground/NOUN (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         ground
#         </font>
# <font
#             color="#A52A2A"
#             title="like/ADP (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         like
#         </font>
# <font
#             color="#800080"
#             title="take/VERB (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         take
#         </font>
# <font
#             color="#800080"
#             title="keep/VERB (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         keep
#         </font>
# <font
#             color="#32CD32"
#             title="back/ADV (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         back
#         </font>
# <font
#             color="#FFA500"
#             title="stone/NOUN (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         stone
#         </font>
# <font
#             color="#FFA500"
#             title="neighbor/NOUN (4)"
#             style="font-size: 136.11111111111111%"
#         >
#         neighbor
#         </font>
# <font
#             color="#4E8975"
#             title="one/ADJ (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         one
#         </font>
# <font
#             color="#FFA500"
#             title="day/NOUN (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             title="fire/NOUN (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         fire
#         </font>
# <font
#             color="#800080"
#             title="leave/VERB (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         leave
#         </font>
# <font
#             color="#4E8975"
#             title="dark/ADJ (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         dark
#         </font>
# <font
#             color="#FFA500"
#             title="boy/NOUN (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         boy
#         </font>
# <font
#             color="#800080"
#             title="bend/VERB (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         bend
#         </font>
# <font
#             color="#FFA500"
#             title="sun/NOUN (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         sun
#         </font>
# <font
#             color="#FFA500"
#             title="snow/NOUN (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         snow
#         </font>
# <font
#             color="#800080"
#             title="break/VERB (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         break
#         </font>
# <font
#             color="#EDDA74"
#             title="though/SCONJ (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         though
#         </font>
# <font
#             color="#FFA500"
#             title="cow/NOUN (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         cow
#         </font>
# <font
#             color="#800080"
#             title="learn/VERB (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         learn
#         </font>
# <font
#             color="#800080"
#             title="climb/VERB (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         climb
#         </font>
# <font
#             color="#FFA500"
#             title="way/NOUN (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         way
#         </font>
# <font
#             color="#6698FF"
#             title="two/NUM (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         two
#         </font>
# <font
#             color="#800080"
#             title="stop/VERB (3)"
#             style="font-size: 105.55555555555556%"
#         >
#         stop
#         </font>
# <font
#             color="#FF0000"
#             title="nothing/PRON (2)"
#             style="font-size: 75.0%"
#         >
#         nothing
#         </font>
# <font
#             color="#FFA500"
#             title="gold/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         gold
#         </font>
# <font
#             color="#800080"
#             title="hold/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         hold
#         </font>
# <font
#             color="#0000FF"
#             title="can/AUX (2)"
#             style="font-size: 75.0%"
#         >
#         can
#         </font>
# <font
#             color="#800080"
#             title="stay/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         stay
#         </font>
# <font
#             color="#FFA500"
#             title="line/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         line
#         </font>
# <font
#             color="#800080"
#             title="swing/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         swing
#         </font>
# <font
#             color="#FFA500"
# <h1>poe</h1>
# <font
#             color="#FF0000"
#             title="thou/PRON (15)"
#             style="font-size: 350.0%"
#         >
#         thou
#         </font>
# <font
#             color="#FFA500"
#             title="door/NOUN (14)"
#             style="font-size: 327.08333333333337%"
#         >
#         door
#         </font>
# <font
#             color="#FFA500"
#             title="sea/NOUN (13)"
#             style="font-size: 304.16666666666663%"
#         >
#         sea
#         </font>
# <font
#             color="#FFA500"
#             title="soul/NOUN (12)"
#             style="font-size: 281.25%"
#         >
#         soul
#         </font>
# <font
#             color="#A52A2A"
#             title="upon/ADP (12)"
#             style="font-size: 281.25%"
#         >
#         upon
#         </font>
# <font
#             color="#32CD32"
#             title="nevermore/ADV (12)"
#             style="font-size: 281.25%"
#         >
#         nevermore
#         </font>
# <font
#             color="#8D38C9"
#             title="Lenore/PROPN (11)"
#             style="font-size: 258.33333333333337%"
#         >
#         Lenore
#         </font>
# <font
#             color="#FFA500"
#             title="chamber/NOUN (11)"
#             style="font-size: 258.33333333333337%"
#         >
#         chamber
#         </font>
# <font
#             color="#800080"
#             title="love/VERB (10)"
#             style="font-size: 235.41666666666666%"
#         >
#         love
#         </font>
# <font
#             color="#8D38C9"
#             title="Raven/PROPN (10)"
#             style="font-size: 235.41666666666666%"
#         >
#         Raven
#         </font>
# <font
#             color="#FFA500"
#             title="bird/NOUN (10)"
#             style="font-size: 235.41666666666666%"
#         >
#         bird
#         </font>
# <font
#             color="#FFA500"
#             title="eye/NOUN (9)"
#             style="font-size: 212.5%"
#         >
#         eye
#         </font>
# <font
#             color="#FFA500"
#             title="heart/NOUN (8)"
#             style="font-size: 189.58333333333331%"
#         >
#         heart
#         </font>
# <font
#             color="#32CD32"
#             title="still/ADV (8)"
#             style="font-size: 189.58333333333331%"
#         >
#         still
#         </font>
# <font
#             color="#800080"
#             title="say/VERB (8)"
#             style="font-size: 189.58333333333331%"
#         >
#         say
#         </font>
# <font
#             color="#FF0000"
#             title="nothing/PRON (8)"
#             style="font-size: 189.58333333333331%"
#         >
#         nothing
#         </font>
# <font
#             color="#8D38C9"
#             title="Annabel/PROPN (8)"
#             style="font-size: 189.58333333333331%"
#         >
#         Annabel
#         </font>
# <font
#             color="#8D38C9"
#             title="Lee/PROPN (8)"
#             style="font-size: 189.58333333333331%"
#         >
#         Lee
#         </font>
# <font
#             color="#800080"
#             title="lie/VERB (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         lie
#         </font>
# <font
#             color="#FFA500"
#             title="shadow/NOUN (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         shadow
#         </font>
# <font
#             color="#A52A2A"
#             title="within/ADP (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         within
#         </font>
# <font
#             color="#32CD32"
#             title="now/ADV (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         now
#         </font>
# <font
#             color="#FFA500"
#             title="wind/NOUN (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         wind
#         </font>
# <font
#             color="#800080"
#             title="come/VERB (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         come
#         </font>
# <font
#             color="#0000FF"
#             title="shall/AUX (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         shall
#         </font>
# <font
#             color="#32CD32"
#             title="far/ADV (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         far
#         </font>
# <font
#             color="#FFA500"
#             title="angel/NOUN (7)"
#             style="font-size: 166.66666666666669%"
#         >
#         angel
#         </font>
# <font
#             color="#800080"
#             title="leave/VERB (6)"
#             style="font-size: 143.75%"
#         >
#         leave
#         </font>
# <font
#             color="#800080"
#             title="let/VERB (6)"
#             style="font-size: 143.75%"
#         >
#         let
#         </font>
# <font
#             color="#800080"
#             title="die/VERB (6)"
#             style="font-size: 143.75%"
#         >
#         die
#         </font>
# <font
#             color="#A52A2A"
#             title="o'er/ADP (6)"
#             style="font-size: 143.75%"
#         >
#         o'er
#         </font>
# <font
#             color="#800080"
#             title="tell/VERB (6)"
#             style="font-size: 143.75%"
#         >
#         tell
#         </font>
# <font
#             color="#FFA500"
#             title="name/NOUN (6)"
#             style="font-size: 143.75%"
#         >
#         name
#         </font>
# <font
#             color="#FFA500"
#             title="bust/NOUN (6)"
#             style="font-size: 143.75%"
#         >
#         bust
#         </font>
# <font
#             color="#800080"
#             title="sit/VERB (6)"
#             style="font-size: 143.75%"
#         >
#         sit
#         </font>
# <font
#             color="#800080"
#             title="feel/VERB (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         feel
#         </font>
# <font
#             color="#32CD32"
#             title="ever/ADV (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         ever
#         </font>
# <font
#             color="#FFA500"
#             title="stone/NOUN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         stone
#         </font>
# <font
#             color="#800080"
#             title="fly/VERB (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         fly
#         </font>
# <font
#             color="#FFA500"
#             title="love/NOUN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         love
#         </font>
# <font
#             color="#FFA500"
#             title="lie/NOUN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         lie
#         </font>
# <font
#             color="#8D38C9"
#             title="Heaven/PROPN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         Heaven
#         </font>
# <font
#             color="#6698FF"
#             title="one/NUM (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         one
#         </font>
# <font
#             color="#800080"
#             title="dream/VERB (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         dream
#         </font>
# <font
#             color="#8D38C9"
#             title="Eldorado/PROPN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         Eldorado
#         </font>
# <font
#             color="#FFA500"
#             title="kingdom/NOUN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         kingdom
#         </font>
# <font
#             color="#FFA500"
#             title="maiden/NOUN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         maiden
#         </font>
# <font
#             color="#32CD32"
#             title="never/ADV (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         never
#         </font>
# <font
#             color="#FFA500"
#             title="word/NOUN (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         word
#         </font>
# <font
#             color="#800080"
#             title="quoth/VERB (5)"
#             style="font-size: 120.83333333333334%"
#         >
#         quoth
#         </font>
# <font
#             color="#FFA500"
#             title="day/NOUN (4)"
#             style="font-size: 97.91666666666667%"
#         >
#         day
#         </font>
# <font
#             color="#800080"
# <h1>shakespeare</h1>
# <font
#             color="#FF0000"
#             title="thou/PRON (12)"
#             style="font-size: 350.0%"
#         >
#         thou
#         </font>
# <font
#             color="#0000FF"
#             title="shall/AUX (9)"
#             style="font-size: 275.0%"
#         >
#         shall
#         </font>
# <font
#             color="#FFA500"
#             title="sonnet/NOUN (7)"
#             style="font-size: 225.0%"
#         >
#         sonnet
#         </font>
# <font
#             color="#FFA500"
#             title="eye/NOUN (6)"
#             style="font-size: 200.0%"
#         >
#         eye
#         </font>
# <font
#             color="#800080"
#             title="love/VERB (5)"
#             style="font-size: 175.0%"
#         >
#         love
#         </font>
# <font
#             color="#FFA500"
#             title="time/NOUN (4)"
#             style="font-size: 150.0%"
#         >
#         time
#         </font>
# <font
#             color="#FFA500"
#             title="death/NOUN (4)"
#             style="font-size: 150.0%"
#         >
#         death
#         </font>
# <font
#             color="#FFA500"
#             title="love/NOUN (4)"
#             style="font-size: 150.0%"
#         >
#         love
#         </font>
# <font
#             color="#FFA500"
#             title="woe/NOUN (4)"
#             style="font-size: 150.0%"
#         >
#         woe
#         </font>
# <font
#             color="#0000FF"
#             title="can/AUX (4)"
#             style="font-size: 150.0%"
#         >
#         can
#         </font>
# <font
#             color="#800080"
#             title="see/VERB (4)"
#             style="font-size: 150.0%"
#         >
#         see
#         </font>
# <font
#             color="#FFA500"
#             title="summer/NOUN (3)"
#             style="font-size: 125.0%"
#         >
#         summer
#         </font>
# <font
#             color="#800080"
#             title="shake/VERB (3)"
#             style="font-size: 125.0%"
#         >
#         shake
#         </font>
# <font
#             color="#4E8975"
#             title="fair/ADJ (3)"
#             style="font-size: 125.0%"
#         >
#         fair
#         </font>
# <font
#             color="#32CD32"
#             title="never/ADV (3)"
#             style="font-size: 125.0%"
#         >
#         never
#         </font>
# <font
#             color="#FFA500"
#             title="war/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         war
#         </font>
# <font
#             color="#FFA500"
#             title="fire/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         fire
#         </font>
# <font
#             color="#800080"
#             title="find/VERB (2)"
#             style="font-size: 100.0%"
#         >
#         find
#         </font>
# <font
#             color="#FFA500"
#             title="doom/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         doom
#         </font>
# <font
#             color="#493D26"
#             title="behold/INTJ (2)"
#             style="font-size: 100.0%"
#         >
#         behold
#         </font>
# <font
#             color="#FF0000"
#             title="nothing/PRON (2)"
#             style="font-size: 100.0%"
#         >
#         nothing
#         </font>
# <font
#             color="#FFA500"
#             title="art/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         art
#         </font>
# <font
#             color="#800080"
#             title="make/VERB (2)"
#             style="font-size: 100.0%"
#         >
#         make
#         </font>
# <font
#             color="#A52A2A"
#             title="like/ADP (2)"
#             style="font-size: 100.0%"
#         >
#         like
#         </font>
# <font
#             color="#800080"
#             title="go/VERB (2)"
#             style="font-size: 100.0%"
#         >
#         go
#         </font>
# <font
#             color="#800080"
#             title="leave/VERB (2)"
#             style="font-size: 100.0%"
#         >
#         leave
#         </font>
# <font
#             color="#4E8975"
#             title="sweet/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         sweet
#         </font>
# <font
#             color="#FFA500"
#             title="thing/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         thing
#         </font>
# <font
#             color="#4E8975"
#             title="new/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         new
#         </font>
# <font
#             color="#4E8975"
#             title="dear/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         dear
#         </font>
# <font
#             color="#FFA500"
#             title="friend/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         friend
#         </font>
# <font
#             color="#FFA500"
#             title="night/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         night
#         </font>
# <font
#             color="#4E8975"
#             title="long/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         long
#         </font>
# <font
#             color="#800080"
#             title="think/VERB (2)"
#             style="font-size: 100.0%"
#         >
#         think
#         </font>
# <font
#             color="#FFA500"
#             title="day/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             title="hath/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         hath
#         </font>
# <font
#             color="#4E8975"
#             title="eternal/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         eternal
#         </font>
# <font
#             color="#8D38C9"
#             title="Death/PROPN (2)"
#             style="font-size: 100.0%"
#         >
#         Death
#         </font>
# <font
#             color="#32CD32"
#             title="long/ADV (2)"
#             style="font-size: 100.0%"
#         >
#         long
#         </font>
# <font
#             color="#FFA500"
#             title="man/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         man
#         </font>
# <font
#             color="#FFA500"
#             title="life/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         life
#         </font>
# <font
#             color="#A52A2A"
#             title="upon/ADP (2)"
#             style="font-size: 100.0%"
#         >
#         upon
#         </font>
# <font
#             color="#8D38C9"
#             title="see'st/PROPN (2)"
#             style="font-size: 100.0%"
#         >
#         see'st
#         </font>
# <font
#             color="#4E8975"
#             title="black/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         black
#         </font>
# <font
#             color="#800080"
#             title="take/VERB (2)"
#             style="font-size: 100.0%"
#         >
#         take
#         </font>
# <font
#             color="#0000FF"
#             title="must/AUX (2)"
#             style="font-size: 100.0%"
#         >
#         must
#         </font>
# <font
#             color="#32CD32"
#             title="well/ADV (2)"
#             style="font-size: 100.0%"
#         >
#         well
#         </font>
# <font
#             color="#800080"
#             title="alter/VERB (2)"
#             style="font-size: 100.0%"
#         >
#         alter
#         </font>
# <font
#             color="#32CD32"
#             title="ever/ADV (2)"
#             style="font-size: 100.0%"
#         >
#         ever
#         </font>
# <font
#             color="#8D38C9"
#             title="Love/PROPN (2)"
#             style="font-size: 100.0%"
#         >
#         Love
#         </font>
# <font
#             color="#FFA500"
#             title="lip/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         lip
#         </font>
# <font
#             color="#FFA500"
#             title="cheek/NOUN (2)"
#             style="font-size: 100.0%"
#         >
#         cheek
#         </font>
# <font
#             color="#32CD32"
#             title="far/ADV (2)"
#             style="font-size: 100.0%"
#         >
#         far
#         </font>
# <font
#             color="#4E8975"
#             title="red/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         red
#         </font>
# <font
#             color="#4E8975"
#             title="white/ADJ (2)"
#             style="font-size: 100.0%"
#         >
#         white
#         </font>
# <font
# <h1>whitman</h1>
# <font
#             color="#8D38C9"
#             title="O/PROPN (9)"
#             style="font-size: 350.0%"
#         >
#         O
#         </font>
# <font
#             color="#800080"
#             title="sing/VERB (7)"
#             style="font-size: 271.42857142857144%"
#         >
#         sing
#         </font>
# <font
#             color="#6698FF"
#             title="one/NUM (7)"
#             style="font-size: 271.42857142857144%"
#         >
#         one
#         </font>
# <font
#             color="#32CD32"
#             title="alone/ADV (6)"
#             style="font-size: 232.14285714285714%"
#         >
#         alone
#         </font>
# <font
#             color="#FFA500"
#             title="book/NOUN (5)"
#             style="font-size: 192.85714285714286%"
#         >
#         book
#         </font>
# <font
#             color="#800080"
#             title="make/VERB (5)"
#             style="font-size: 192.85714285714286%"
#         >
#         make
#         </font>
# <font
#             color="#FFA500"
#             title="love/NOUN (5)"
#             style="font-size: 192.85714285714286%"
#         >
#         love
#         </font>
# <font
#             color="#800080"
#             title="love/VERB (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         love
#         </font>
# <font
#             color="#800080"
#             title="utter/VERB (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         utter
#         </font>
# <font
#             color="#FFA500"
#             title="hour/NOUN (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         hour
#         </font>
# <font
#             color="#FFA500"
#             title="joy/NOUN (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         joy
#         </font>
# <font
#             color="#8D38C9"
#             title="o/PROPN (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         o
#         </font>
# <font
#             color="#FFA500"
#             title="day/NOUN (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         day
#         </font>
# <font
#             color="#FFA500"
#             title="ocean/NOUN (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         ocean
#         </font>
# <font
#             color="#800080"
#             title="look/VERB (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         look
#         </font>
# <font
#             color="#800080"
#             title="know/VERB (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         know
#         </font>
# <font
#             color="#800080"
#             title="think/VERB (4)"
#             style="font-size: 153.57142857142856%"
#         >
#         think
#         </font>
# <font
#             color="#FFA500"
#             title="man/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         man
#         </font>
# <font
#             color="#FFA500"
#             title="word/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         word
#         </font>
# <font
#             color="#0000FF"
#             title="will/AUX (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         will
#         </font>
# <font
#             color="#4E8975"
#             title="one/ADJ (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         one
#         </font>
# <font
#             color="#32CD32"
#             title="much/ADV (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         much
#         </font>
# <font
#             color="#4E8975"
#             title="free/ADJ (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         free
#         </font>
# <font
#             color="#FFA500"
#             title="space/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         space
#         </font>
# <font
#             color="#FFA500"
#             title="air/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         air
#         </font>
# <font
#             color="#800080"
#             title="lose/VERB (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         lose
#         </font>
# <font
#             color="#FFA500"
#             title="life/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         life
#         </font>
# <font
#             color="#800080"
#             title="see/VERB (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         see
#         </font>
# <font
#             color="#8D38C9"
#             title="Louisiana/PROPN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         Louisiana
#         </font>
# <font
#             color="#800080"
#             title="grow/VERB (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         grow
#         </font>
# <font
#             color="#A52A2A"
#             title="without/ADP (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         without
#         </font>
# <font
#             color="#4E8975"
#             title="joyous/ADJ (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         joyous
#         </font>
# <font
#             color="#FFA500"
#             title="leaf/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         leaf
#         </font>
# <font
#             color="#FFA500"
#             title="friend/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         friend
#         </font>
# <font
#             color="#FFA500"
#             title="lover/NOUN (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         lover
#         </font>
# <font
#             color="#800080"
#             title="repay/VERB (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         repay
#         </font>
# <font
#             color="#800080"
#             title="leave/VERB (3)"
#             style="font-size: 114.28571428571428%"
#         >
#         leave
#         </font>
# <font
#             color="#800080"
#             title="besiege/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         besiege
#         </font>
# <font
#             color="#FFA500"
#             title="place/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         place
#         </font>
# <font
#             color="#FFA500"
#             title="artillery/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         artillery
#         </font>
# <font
#             color="#800080"
#             title="shut/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         shut
#         </font>
# <font
#             color="#FFA500"
#             title="door/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         door
#         </font>
# <font
#             color="#FFA500"
#             title="library/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         library
#         </font>
# <font
#             color="#FFA500"
#             title="shelf/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         shelf
#         </font>
# <font
#             color="#32CD32"
#             title="yet/ADV (2)"
#             style="font-size: 75.0%"
#         >
#         yet
#         </font>
# <font
#             color="#800080"
#             title="need/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         need
#         </font>
# <font
#             color="#800080"
#             title="bring/VERB (2)"
#             style="font-size: 75.0%"
#         >
#         bring
#         </font>
# <font
#             color="#FFA500"
#             title="intellect/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         intellect
#         </font>
# <font
#             color="#FFA500"
#             title="step/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         step
#         </font>
# <font
#             color="#FFA500"
#             title="plea/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         plea
#         </font>
# <font
#             color="#FFA500"
#             title="form/NOUN (2)"
#             style="font-size: 75.0%"
#         >
#         form
#         </font>
# <font
#             color="#FFA500"
#             title="power/NOUN (2)"
#             style="font-size: 75.0%"
# <h1>yeats</h1>
# <font
#             color="#FFA500"
#             title="heart/NOUN (15)"
#             style="font-size: 350.0%"
#         >
#         heart
#         </font>
# <font
#             color="#32CD32"
#             title="now/ADV (9)"
#             style="font-size: 223.07692307692307%"
#         >
#         now
#         </font>
# <font
#             color="#800080"
#             title="come/VERB (8)"
#             style="font-size: 201.9230769230769%"
#         >
#         come
#         </font>
# <font
#             color="#800080"
#             title="go/VERB (8)"
#             style="font-size: 201.9230769230769%"
#         >
#         go
#         </font>
# <font
#             color="#A52A2A"
#             title="upon/ADP (8)"
#             style="font-size: 201.9230769230769%"
#         >
#         upon
#         </font>
# <font
#             color="#800080"
#             title="make/VERB (8)"
#             style="font-size: 201.9230769230769%"
#         >
#         make
#         </font>
# <font
#             color="#0000FF"
#             title="will/AUX (8)"
#             style="font-size: 201.9230769230769%"
#         >
#         will
#         </font>
# <font
#             color="#800080"
#             title="know/VERB (6)"
#             style="font-size: 159.6153846153846%"
#         >
#         know
#         </font>
# <font
#             color="#FFA500"
#             title="man/NOUN (6)"
#             style="font-size: 159.6153846153846%"
#         >
#         man
#         </font>
# <font
#             color="#800080"
#             title="give/VERB (6)"
#             style="font-size: 159.6153846153846%"
#         >
#         give
#         </font>
# <font
#             color="#FFA500"
#             title="beauty/NOUN (5)"
#             style="font-size: 138.46153846153845%"
#         >
#         beauty
#         </font>
# <font
#             color="#8D38C9"
#             title="O/PROPN (5)"
#             style="font-size: 138.46153846153845%"
#         >
#         O
#         </font>
# <font
#             color="#FFA500"
#             title="eye/NOUN (5)"
#             style="font-size: 138.46153846153845%"
#         >
#         eye
#         </font>
# <font
#             color="#800080"
#             title="seem/VERB (5)"
#             style="font-size: 138.46153846153845%"
#         >
#         seem
#         </font>
# <font
#             color="#FFA500"
#             title="peace/NOUN (5)"
#             style="font-size: 138.46153846153845%"
#         >
#         peace
#         </font>
# <font
#             color="#0000FF"
#             title="can/AUX (5)"
#             style="font-size: 138.46153846153845%"
#         >
#         can
#         </font>
# <font
#             color="#800080"
#             title="bring/VERB (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         bring
#         </font>
# <font
#             color="#4E8975"
#             title="old/ADJ (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         old
#         </font>
# <font
#             color="#FFA500"
#             title="water/NOUN (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         water
#         </font>
# <font
#             color="#32CD32"
#             title="still/ADV (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         still
#         </font>
# <font
#             color="#800080"
#             title="hear/VERB (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         hear
#         </font>
# <font
#             color="#FFA500"
#             title="head/NOUN (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         head
#         </font>
# <font
#             color="#FFA500"
#             title="day/NOUN (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         day
#         </font>
# <font
#             color="#A52A2A"
#             title="like/ADP (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         like
#         </font>
# <font
#             color="#FFA500"
#             title="thing/NOUN (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         thing
#         </font>
# <font
#             color="#8D38C9"
#             title="Second/PROPN (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         Second
#         </font>
# <font
#             color="#32CD32"
#             title="never/ADV (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         never
#         </font>
# <font
#             color="#800080"
#             title="dream/VERB (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         dream
#         </font>
# <font
#             color="#800080"
#             title="say/VERB (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         say
#         </font>
# <font
#             color="#8D38C9"
#             title="Time/PROPN (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         Time
#         </font>
# <font
#             color="#800080"
#             title="burn/VERB (4)"
#             style="font-size: 117.3076923076923%"
#         >
#         burn
#         </font>
# <font
#             color="#A52A2A"
#             title="among/ADP (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         among
#         </font>
# <font
#             color="#FFA500"
#             title="cloud/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         cloud
#         </font>
# <font
#             color="#800080"
#             title="bid/VERB (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         bid
#         </font>
# <font
#             color="#FFA500"
#             title="crowd/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         crowd
#         </font>
# <font
#             color="#FFA500"
#             title="year/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         year
#         </font>
# <font
#             color="#FFA500"
#             title="blood/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         blood
#         </font>
# <font
#             color="#4E8975"
#             title="young/ADJ (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         young
#         </font>
# <font
#             color="#0000FF"
#             title="can not/AUX (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         can not
#         </font>
# <font
#             color="#32CD32"
#             title="well/ADV (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         well
#         </font>
# <font
#             color="#4E8975"
#             title="great/ADJ (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         great
#         </font>
# <font
#             color="#FFA500"
#             title="wing/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         wing
#         </font>
# <font
#             color="#800080"
#             title="grow/VERB (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         grow
#         </font>
# <font
#             color="#800080"
#             title="fall/VERB (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         fall
#         </font>
# <font
#             color="#FFA500"
#             title="face/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         face
#         </font>
# <font
#             color="#FFA500"
#             title="hand/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         hand
#         </font>
# <font
#             color="#8D38C9"
#             title="Coming/PROPN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         Coming
#         </font>
# <font
#             color="#800080"
#             title="turn/VERB (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         turn
#         </font>
# <font
#             color="#FFA500"
#             title="lion/NOUN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         lion
#         </font>
# <font
#             color="#800080"
#             title="drop/VERB (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         drop
#         </font>
# <font
#             color="#8D38C9"
#             title="o/PROPN (3)"
#             style="font-size: 96.15384615384616%"
#         >
#         o
